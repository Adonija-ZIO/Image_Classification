# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, shutil, tarfile, requests
import tensorflow as tf
URL = 'http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar' 

zip_dir = tf.keras.utils.get_file('/content/drive/MyDrive/Colab_Notebooks/StanfordDogs', origin=URL, untar=True,extract=True)

# %%
fname = '/content/drive/MyDrive/Colab_Notebooks/import_data/StanfordDogs.tar.gz'
     
tar = tarfile.open(fname)
tar.extractall(path="/content/drive/MyDrive/Colab_Notebooks/data")
tar.close()

# %% [markdown]
# **Author**
#
# *Adonija ZIO*
